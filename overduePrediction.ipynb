# %%
import numpy as np
import pandas as pd

df = pd.read_csv('/Users/ishi/Desktop/data0802.csv', low_memory=False)

# %%
df.info
# Out:
# <bound method DataFrame.info of        本次测试编号        保险起期        保险止期 新续共保标志  颜色  座位数        初登日期    车损险-保额  \
# 0           1    2015/1/1  2015/12/31     续保  其他    5    2011/1/5   91620.0
# 1           2    2015/1/6    2016/1/5     新保   蓝    5   2012/12/7  103400.0
# 2           3    2015/1/1    2016/1/1     续保  其他    5    2009/4/9  167220.0
# 3           4    2015/1/1  2015/12/31     新保   蓝    5   2011/9/22  252900.0
# 4           5    2015/1/1  2015/12/31     续保   蓝    5    2009/2/3  126800.0
# 5           6    2015/1/5    2016/1/4     续保   蓝    5   2010/1/14  152820.0
# 6           7    2015/1/6    2016/1/5     新保   蓝    5   2012/1/11  100710.0
# 7           8    2015/1/3    2016/1/2     新保   蓝    5   2007/1/10   88920.0
# 8           9    2015/1/3    2016/1/2     新保   蓝    5    2011/1/2   45810.0
# 9          10    2015/1/1  2015/12/31     新保   蓝    5    2014/1/8   63270.0
# 10         11    2015/1/2    2016/1/1     新保   蓝    5    2014/1/2  106020.0
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of        本次测试编号        保险起期        保险止期 新续共保标志  颜色  座位数        初登日期    车损险-保额  \
# 0           1    2015/1/1  2015/12/31     续保  其他    5    2011/1/5   91620.0
# 1           2    2015/1/6    2016/1/5     新保   蓝    5   2012/12/7  103400.0
# 2           3    2015/1/1    2016/1/1     续保  其他    5    2009/4/9  167220.0
# 3           4    2015/1/1  2015/12/31     新保   蓝    5   2011/9/22  252900.0
# 4           5    2015/1/1  2015/12/31     续保   蓝    5    2009/2/3  126800.0
# 5           6    2015/1/5    2016/1/4     续保   蓝    5   2010/1/14  152820.0
# 6           7    2015/1/6    2016/1/5     新保   蓝    5   2012/1/11  100710.0
# 7           8    2015/1/3    2016/1/2     新保   蓝    5   2007/1/10   88920.0
# 8           9    2015/1/3    2016/1/2     新保   蓝    5    2011/1/2   45810.0
# 9          10    2015/1/1  2015/12/31     新保   蓝    5    2014/1/8   63270.0
# 10         11    2015/1/2    2016/1/1     新保   蓝    5    2014/1/2  106020.0
# ...

# %%
for i, v in enumerate(df.columns):
    print(i, v)
# Out:
# 0 本次测试编号
# 1 保险起期
# 2 保险止期
# 3 新续共保标志
# 4 颜色
# 5 座位数
# 6 初登日期
# 7 车损险-保额
# 8 三责险-保额
# 9 盗抢险-保额
# 10 其他险-保额
# 11 车损险-含税保费
# 12 三责险-含税保费
# 13 盗抢险-含税保费
# 14 其他险-含税保费
# 15 总保额
# 16 含税总保费
# 17 优惠系数
# 18 优惠额
# 19 新车购置价
# 20 实收保费
# 21 折前保费
# 22 机构
# 23 厂牌车型名称
# 24 新旧车
# 25 渠道代码
# 26 上年出险次数-商业险
# 27 本期内是否理赔
# 28 已决赔款
# 29 车损险_已决赔款
# 30 三责险_已决赔款
# 31 车商收购价
# 32 个人交易价
# 33 车商交易价
# 34 model_id
# 35 是否增压
# 36 发动机功率
# 37 变速箱类型
# 38 油箱类型
# 39 门数
# 40 是否有倒车成像
# 41 是否有倒车雷达
# 42 多功能方向盘
# 43 排量
# 44 最大扭矩
# 45 最高时速
# 46 百公里加速
# 47 驱动类型
# 48 ABS
# 49 EBD
# 50 EBA
# 51 ASR
# 52 ESP
# 53 车身宽度
# 54 整备质量
# 55 最小离地间隙
# 56 主动刹车
# 57 夜视系统
# 58 并线辅助
# 59 前驻车雷达
# 60 后驻车雷达
# 61 实测100-0km/h制动(m)
# 62 疲劳驾驶提示
# 63 车道保持辅助系统
# 64 日间行驶灯
# 65 防炫目后视镜
# 66 轴距
# 67 长度
# 68 高度
# 69 品牌
# 70 车系
# 71 车型
# 72 MSRP

# %%
 df.dtypes
# Out:
# 本次测试编号                int64
# 保险起期                 object
# 保险止期                 object
# 新续共保标志               object
# 颜色                   object
# 座位数                   int64
# 初登日期                 object
# 车损险-保额              float64
# 三责险-保额                int64
# 盗抢险-保额              float64
# 其他险-保额              float64
# 车损险-含税保费            float64
# 三责险-含税保费            float64
# 盗抢险-含税保费            float64
# 其他险-含税保费            float64
# 总保额                 float64
# 含税总保费               float64
# 优惠系数                float64
# 优惠额                 float64
# 新车购置价               float64
# 实收保费                float64
# 折前保费                float64
# 机构                   object
# 厂牌车型名称               object
# 新旧车                  object
# 渠道代码                 object
# 上年出险次数-商业险           object
# 本期内是否理赔               int64
# 已决赔款                float64
# 车损险_已决赔款            float64
#                      ...
# 排量                    int64
# 最大扭矩                float64
# ...
